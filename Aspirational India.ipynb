# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
path = r"C:\Users\parik\Documents\Data sets\aspirations\drive-download-20220221T055656Z-001\aspirational_india_20210101_20210430_R_csv\aspirational_india_20210101_20210430_R.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    WAVE_NO     HH_ID            STATE    HR   DISTRICT REGION_TYPE  \
# 0       22  77051739  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 1       22  61287374  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 2       22  34049553  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 3       22  92526123  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 4       22  61508707  Jammu & Kashmir  HR 1  Bandipore       RURAL
#
#         STRATUM       PSU_ID MONTH_SLOT RESPONSE_STATUS  ...  \
# 0  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 1  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 2  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 3  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 4  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
#
#   IS_THIS_GOOD_TIME_TO_BUY_CONSUMER_DURABLES        TYPE_OF_ROOF  \
# 0                         Data Not Available  Data Not Available
# ...

# %%
cols = list(df.columns)

# %%
num_cols = df._get_numeric_data().columns

# %%
categoricals = list(set(list(df.columns)) - set(num_cols))
categoricals.remove("PSU_ID")
len(categoricals),16*17
# Out:
# (275, 272)

# %%
cat_dict = {}
counter = 1
start = 0
for x in range((len(categoricals)//16)+1):
    name = "cat"+str(counter)
    cat_dict[name]=categoricals[start:start+16]
    counter+=1
    start +=16

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat1[counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat2"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat3"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat4"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat5"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat6"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat7"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat8"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat9"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat10"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat11"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat12"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat13"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat14"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat15"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat16"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat16"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 4,4
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat17"][counter]), ax = axs[r,c])
        counter+=1

# %%
ax_rows,ax_cols = 3,1
fig, axs = plt.subplots(ax_rows,ax_cols,figsize=(25,20))

axes_dict = {}
counter=0
for r in range(ax_rows):
    for c in range(ax_cols):
        axes_dict[cat1[counter]]=(r,c)
        sns.histplot(df,x= str(cat_dict["cat18"][counter]), ax = axs[r])
        counter+=1
