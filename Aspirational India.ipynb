# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\parik\Documents\Data sets\aspirations\drive-download-20220221T055656Z-001\aspirational_india_20210101_20210430_R_csv\aspirational_india_20210101_20210430_R.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    WAVE_NO     HH_ID            STATE    HR   DISTRICT REGION_TYPE  \
# 0       22  77051739  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 1       22  61287374  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 2       22  34049553  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 3       22  92526123  Jammu & Kashmir  HR 1  Bandipore       RURAL
# 4       22  61508707  Jammu & Kashmir  HR 1  Bandipore       RURAL
#
#         STRATUM       PSU_ID MONTH_SLOT RESPONSE_STATUS  ...  \
# 0  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 1  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 2  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 3  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
# 4  HR 1_RURAL_R  PSU_ID_7959   Jan 2021    Non-Response  ...
#
#   IS_THIS_GOOD_TIME_TO_BUY_CONSUMER_DURABLES        TYPE_OF_ROOF  \
# 0                         Data Not Available  Data Not Available
# ...

# %%
list(df.columns)
# Out:
# ['WAVE_NO',
#  'HH_ID',
#  'STATE',
#  'HR',
#  'DISTRICT',
#  'REGION_TYPE',
#  'STRATUM',
#  'PSU_ID',
#  'MONTH_SLOT',
#  'RESPONSE_STATUS',
#  'REASON_FOR_NON_RESPONSE',
#  'FAMILY_SHIFTED',
#  'HH_WEIGHT_W',
#  'HH_WEIGHT_FOR_COUNTRY_W',
#  'HH_WEIGHT_FOR_STATE_W',
#  'HH_NON_RESPONSE_W',
#  'HH_NON_RESPONSE_FOR_COUNTRY_W',
#  'HH_NON_RESPONSE_FOR_STATE_W',
#  'AGE_GROUP',
#  'INCOME_GROUP',
#  'OCCUPATION_GROUP',
#  'EDUCATION_GROUP',
#  'GENDER_GROUP',
#  'WATER_GROUP',
#  'POWER_GROUP',
#  'TRAVEL_GROUP',
#  'SIZE_GROUP',
#  'HOUSES_OWNED',
#  'BOUGHT_HOUSE',
#  'WILL_BUY_HOUSE',
#  'WILL_BUY_HOUSE_NOW',
#  'GOOD_TIME_TO_BUY_HOUSE',
#  'REFRIGERATORS_OWNED',
#  'BOUGHT_REFRIGERATOR',
#  'WILL_BUY_REFRIGERATOR',
#  'WILL_BUY_REFRIGERATOR_NOW',
#  'GOOD_TIME_TO_BUY_REFRIGERATOR',
#  'AIR_CONDITIONERS_OWNED',
#  'BOUGHT_AIR_CONDITIONER',
#  'WILL_BUY_AIR_CONDITIONER',
#  'WILL_BUY_AIR_CONDITIONER_NOW',
#  'GOOD_TIME_TO_BUY_AIR_CONDITIONER',
#  'COOLERS_OWNED',
# ...

# %%
df['BORROWED_FOR_WEDDING'].unique()
# Out:
# array(['N', 'Data Not Available', 'Y'], dtype=object)

# %%
df[df['BORROWED_FOR_WEDDING']=='Y']
# Out:
#         WAVE_NO     HH_ID             STATE      HR          DISTRICT  \
# 191          22  39477262   Jammu & Kashmir    HR 1         Bandipore
# 3139         22  28220276  Himachal Pradesh    HR 3               Una
# 3235         22  53512212  Himachal Pradesh    HR 3             Solan
# 3245         22  94088128  Himachal Pradesh    HR 3             Solan
# 3247         22  38874354  Himachal Pradesh    HR 3             Solan
# ...         ...       ...               ...     ...               ...
# 175503       22  63317912           Tripura  HR 109     North Tripura
# 175537       22  64408703           Tripura  HR 109     North Tripura
# 175563       22  56804457           Tripura  HR 109     North Tripura
# 175614       22  72843659           Tripura  HR 109     North Tripura
# 175708       22  87985798         Meghalaya  HR 110  East Khasi Hills
#
#        REGION_TYPE         STRATUM        PSU_ID MONTH_SLOT RESPONSE_STATUS  \
# ...
