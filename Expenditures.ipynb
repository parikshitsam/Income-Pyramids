# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import zipfile
# %matplotlib notebook

# %%
# path = r"C:\Users\parik\Documents\Data sets\Consumption Pyramids-20220311T061932Z-001\Consumption Pyramids\Monthly Expenses\consumption_pyramids_20190131_MS_rev_csv\consumption_pyramids_20190131_MS_rev.csv"
# df = pd.read_csv(path)
# df.head()

# %%
exp_cols = list(df.columns)[23:]

# %%
exp_cols
# Out:
# ['TOTAL_EXPENDITURE',
#  'ADJ_TOTAL_EXPENDITURE',
#  'MONTHLY_EXPENSE_ON_FOOD',
#  'ADJ_MONTHLY_EXPENSE_ON_FOOD',
#  'MONTHLY_EXPENSE_ON_CEREALS_AND_PULSES',
#  'MONTHLY_EXPENSE_ON_CEREALS_WHOLEGRAIN',
#  'MONTHLY_EXPENSE_ON_PROCESSED_CEREALS_AND_PULSES',
#  'MONTHLY_EXPENSE_ON_PULSES',
#  'MONTHLY_EXPENSE_ON_EDIBLE_OILS',
#  'ADJ_MONTHLY_EXPENSE_ON_EDIBLE_OILS',
#  'MONTHLY_EXPENSE_ON_GHEE',
#  'MONTHLY_EXPENSE_ON_DRY_SPICES',
#  'MONTHLY_EXPENSE_ON_VEGETABLES_AND_FRUITS',
#  'MONTHLY_EXPENSE_ON_VEGETABLES_AND_WET_SPICES',
#  'ADJ_MONTHLY_EXPENSE_ON_VEGETABLES_AND_WET_SPICES',
#  'MONTHLY_EXPENSE_ON_FRUITS',
#  'ADJ_MONTHLY_EXPENSE_ON_FRUITS',
#  'MONTHLY_EXPENSE_ON_DRY_FRUITS_AND_SAFFRON',
#  'MONTHLY_EXPENSE_ON_POTATOES_AND_ONIONS',
#  'ADJ_MONTHLY_EXPENSE_ON_POTATOES_AND_ONIONS',
#  'MONTHLY_EXPENSE_ON_MILK_AND_MILK_PRODUCTS',
#  'ADJ_MONTHLY_EXPENSE_ON_MILK_AND_MILK_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_MILK_AND_MILK_POWDER',
#  'ADJ_MONTHLY_EXPENSE_ON_MILK_AND_MILK_POWDER',
#  'MONTHLY_EXPENSE_ON_MILK_PRODUCTS',
#  'ADJ_MONTHLY_EXPENSE_ON_MILK_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_MITHAI',
#  'ADJ_MONTHLY_EXPENSE_ON_MITHAI',
#  'MONTHLY_EXPENSE_ON_BREAD',
#  'ADJ_MONTHLY_EXPENSE_ON_BREAD',
#  'MONTHLY_EXPENSE_ON_BISCUITS',
#  'ADJ_MONTHLY_EXPENSE_ON_BISCUITS',
#  'MONTHLY_EXPENSE_ON_SALTY_SNACKS',
#  'ADJ_MONTHLY_EXPENSE_ON_SALTY_SNACKS',
#  'MONTHLY_EXPENSE_ON_NOODLES_AND_FLAKES',
#  'MONTHLY_EXPENSE_ON_NOODLES_AND_PASTA',
#  'MONTHLY_EXPENSE_ON_FLAKES_MUESLI_AND_OATS',
#  'MONTHLY_EXPENSE_ON_CHOCOLATE_CAKE_ICE_CREAM',
#  'ADJ_MONTHLY_EXPENSE_ON_CHOCOLATE_CAKE_ICE_CREAM',
#  'MONTHLY_EXPENSE_ON_CHOCOLATES_AND_CAKES',
#  'ADJ_MONTHLY_EXPENSE_ON_CHOCOLATES_AND_CAKES',
#  'MONTHLY_EXPENSE_ON_ICE_CREAMS',
#  'ADJ_MONTHLY_EXPENSE_ON_ICE_CREAMS',
#  'MONTHLY_EXPENSE_ON_JAM_KETCHUP_PICKLES',
#  'MONTHLY_EXPENSE_ON_HEALTH_SUPPLEMENTS',
#  'MONTHLY_EXPENSE_ON_MEAT_EGGS_AND_FISH',
#  'ADJ_MONTHLY_EXPENSE_ON_MEAT_EGGS_AND_FISH',
#  'MONTHLY_EXPENSE_ON_MEAT_AND_FISH',
#  'ADJ_MONTHLY_EXPENSE_ON_MEAT_AND_FISH',
#  'MONTHLY_EXPENSE_ON_EGGS',
#  'ADJ_MONTHLY_EXPENSE_ON_EGGS',
#  'MONTHLY_EXPENSE_ON_READY_TO_EAT_FOOD',
#  'MONTHLY_EXPENSE_ON_TEA_COFFEE',
#  'MONTHLY_EXPENSE_ON_TEA',
#  'MONTHLY_EXPENSE_ON_COFFEE',
#  'MONTHLY_EXPENSE_ON_SUGAR_AND_OTHER_SWEETENERS',
#  'MONTHLY_EXPENSE_ON_BEVERAGES_AND_WATER',
#  'ADJ_MONTHLY_EXPENSE_ON_BEVERAGES_AND_WATER',
#  'MONTHLY_EXPENSE_ON_BEVERAGES',
#  'MONTHLY_EXPENSE_ON_BOTTLED_WATER',
#  'ADJ_MONTHLY_EXPENSE_ON_BOTTLED_WATER',
#  'MONTHLY_EXPENSE_ON_BABY_FOOD',
#  'MONTHLY_EXPENSE_ON_OTHER_FOODS',
#  'MONTHLY_EXPENSE_ON_INTOXICANTS',
#  'ADJ_MONTHLY_EXPENSE_ON_INTOXICANTS',
#  'MONTHLY_EXPENSE_ON_CIGARETTES_AND_TOBACCO',
#  'ADJ_MONTHLY_EXPENSE_ON_CIGARETTES_AND_TOBACCO',
#  'MONTHLY_EXPENSE_ON_CIGARETTES',
#  'ADJ_MONTHLY_EXPENSE_ON_CIGARETTES',
#  'MONTHLY_EXPENSE_ON_BIDIS',
#  'ADJ_MONTHLY_EXPENSE_ON_BIDIS',
#  'MONTHLY_EXPENSE_ON_OTHER_TOBACCO_PRODUCTS',
#  'ADJ_MONTHLY_EXPENSE_ON_OTHER_TOBACCO_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_LIQUOR',
#  'MONTHLY_EXPENSE_ON_CLOTHING_AND_FOOTWEAR',
#  'MONTHLY_EXPENSE_ON_CLOTHING',
#  'MONTHLY_EXPENSE_ON_FOOTWEAR',
#  'MONTHLY_EXPENSE_ON_CLOTHING_ACCESSORIES',
#  'MONTHLY_EXPENSE_ON_ARTIFICIAL_JEWELLERY',
#  'MONTHLY_EXPENSE_ON_BAGS_WALLETS_WATCHES_GLASSES',
#  'MONTHLY_EXPENSE_ON_GEMS_AND_JEWELLERY',
#  'MONTHLY_EXPENSE_ON_COSMETIC_AND_TOILETRIES',
#  'MONTHLY_EXPENSE_ON_DENTAL_CARE_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_TOOTHPASTE',
#  'MONTHLY_EXPENSE_ON_TOOTHPOWDER',
#  'MONTHLY_EXPENSE_ON_TOOTHBRUSH',
#  'MONTHLY_EXPENSE_ON_BATHING_SOAP',
#  'MONTHLY_EXPENSE_ON_COSMETICS',
#  'MONTHLY_EXPENSE_ON_FACE_WASH',
#  'MONTHLY_EXPENSE_ON_SHAVING_ARTICLES',
#  'MONTHLY_EXPENSE_ON_HAIR_OIL',
#  'MONTHLY_EXPENSE_ON_SHAMPOO_AND_CONDITIONER',
#  'MONTHLY_EXPENSE_ON_OTHER_HAIR_COSMETICS',
#  'MONTHLY_EXPENSE_ON_OTHER_COSMETICS',
#  'MONTHLY_EXPENSE_ON_POWDER',
#  'MONTHLY_EXPENSE_ON_CREAMS',
#  'MONTHLY_EXPENSE_ON_DEODORANTS_AND_PERFUMES',
#  'MONTHLY_EXPENSE_ON_ALL_TYPES_OF_DETERGENT',
#  'MONTHLY_EXPENSE_ON_DETERGENT_BARS',
#  'MONTHLY_EXPENSE_ON_DETERGENT_LIQUIDS_AND_POWDER',
#  'MONTHLY_EXPENSE_ON_SCOURERS',
#  'MONTHLY_EXPENSE_ON_OTHER_HOUSECARE_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_APPLIANCES',
#  'MONTHLY_EXPENSE_ON_KITCHEN_APPLIANCES',
#  'MONTHLY_EXPENSE_ON_HOUSEHOLD_APPLIANCES',
#  'MONTHLY_EXPENSE_ON_MOBILES_AND_ACCESSORIES',
#  'MONTHLY_EXPENSE_ON_RESTAURANTS',
#  'ADJ_MONTHLY_EXPENSE_ON_RESTAURANTS',
#  'MONTHLY_EXPENSE_ON_FOOD_IN_RESTAURANTS',
#  'ADJ_MONTHLY_EXPENSE_ON_FOOD_IN_RESTAURANTS',
#  'MONTHLY_EXPENSE_ON_LIQUOR_IN_RESTAURANTS',
#  'MONTHLY_EXPENSE_ON_RECREATION',
#  'MONTHLY_EXPENSE_ON_ELECTRONIC_STORAGE_DEVICES',
#  'MONTHLY_EXPENSE_ON_ENTERTAINMENT',
#  'MONTHLY_EXPENSE_ON_TOYS',
#  'MONTHLY_EXPENSE_ON_BILLS_AND_RENT',
#  'MONTHLY_EXPENSE_ON_HOUSE_RENT',
#  'MONTHLY_EXPENSE_ON_WATER_CHARGES',
#  'MONTHLY_EXPENSE_ON_SOCIETY_CHARGES',
#  'MONTHLY_EXPENSE_ON_OTHER_TAXES',
#  'MONTHLY_EXPENSE_ON_POWER_AND_FUEL',
#  'ADJ_MONTHLY_EXPENSE_ON_POWER_AND_FUEL',
#  'MONTHLY_EXPENSE_ON_COOKING_FUEL',
#  'MONTHLY_EXPENSE_ON_PETROL_AND_DIESEL',
#  'ADJ_MONTHLY_EXPENSE_ON_PETROL_AND_DIESEL',
#  'MONTHLY_EXPENSE_ON_PETROL_AND_CNG',
#  'ADJ_MONTHLY_EXPENSE_ON_PETROL_AND_CNG',
#  'MONTHLY_EXPENSE_ON_DIESEL',
#  'ADJ_MONTHLY_EXPENSE_ON_DIESEL',
#  'MONTHLY_EXPENSE_ON_ELECTRICITY',
#  'MONTHLY_EXPENSE_ON_TRANSPORT',
#  'ADJ_MONTHLY_EXPENSE_ON_TRANSPORT',
#  'MONTHLY_EXPENSE_ON_BUS_TRAIN_AND_FERRY',
#  'MONTHLY_EXPENSE_ON_OUTSTATION_TAXI_BUS_TRAIN',
#  'MONTHLY_EXPENSE_ON_AUTORICKSHAW_AND_CAB',
#  'ADJ_MONTHLY_EXPENSE_ON_AUTORICKSHAW_AND_CAB',
#  'MONTHLY_EXPENSE_ON_AIRFARE',
#  'MONTHLY_EXPENSE_ON_PARKING_FEES',
#  'MONTHLY_EXPENSE_ON_TOLL_CHARGES',
#  'MONTHLY_EXPENSE_ON_COMMUNICATION_AND_INFO',
#  'MONTHLY_EXPENSE_ON_LANDLINE_PHONE',
#  'MONTHLY_EXPENSE_ON_CELL_PHONE',
#  'MONTHLY_EXPENSE_ON_CABLE_TV',
#  'MONTHLY_EXPENSE_ON_INTERNET',
#  'MONTHLY_EXPENSE_ON_NEWSPAPERS_AND_MAGAZINES',
#  'MONTHLY_EXPENSE_ON_EDUCATION',
#  'MONTHLY_EXPENSE_ON_BOOKS_JOURNALS',
#  'MONTHLY_EXPENSE_ON_SCHOOL_ACADEMIC_BOOKS',
#  'MONTHLY_EXPENSE_ON_FICTION_NON_FICTION_BOOKS',
#  'MONTHLY_EXPENSE_ON_STATIONERY',
#  'MONTHLY_EXPENSE_ON_SCHOOL_COLLEGE_FEES',
#  'MONTHLY_EXPENSE_ON_PRIVATE_TUITION_FEES',
#  'MONTHLY_EXPENSE_ON_HOBBY_CLASSES',
#  'MONTHLY_EXPENSE_ON_SCHOOL_TRANSPORT',
#  'MONTHLY_EXPENSE_ON_ADDITIONAL_PROFESSIONAL_EDUCATION',
#  'MONTHLY_EXPENSE_ON_OVERSEAS_EDUCATION',
#  'MONTHLY_EXPENSE_ON_OTHERS_EDUCATION',
#  'MONTHLY_EXPENSE_ON_HEALTH',
#  'MONTHLY_EXPENSE_ON_MEDICINES',
#  'MONTHLY_EXPENSE_ON_DOCTORS_PHYSIOTHERAPISTS_FEE',
#  'MONTHLY_EXPENSE_ON_MEDICAL_TESTS',
#  'MONTHLY_EXPENSE_ON_HOSPITALISATION_FEES',
#  'MONTHLY_EXPENSE_ON_HEALTH_INSURANCE_PREMIUM',
#  'MONTHLY_EXPENSE_ON_HEALTH_ENHANCEMENT',
#  'MONTHLY_EXPENSE_ON_OTHER_BEAUTY_AND_HYGIENE_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_HYGIENE_PRODUCTS',
#  'MONTHLY_EXPENSE_ON_FITNESS',
#  'MONTHLY_EXPENSE_ON_PARLOR_SPA',
#  'MONTHLY_EXPENSE_ON_ALL_EMIS',
#  'MONTHLY_EXPENSE_ON_EMI_FOR_HOUSE',
#  'MONTHLY_EXPENSE_ON_EMI_FOR_VEHICLES',
#  'MONTHLY_EXPENSE_ON_EMI_FOR_DURABLES',
#  'MONTHLY_EXPENSE_ON_OTHER_EMIS',
#  'MONTHLY_EXPENSE_ON_MISCELLANEOUS',
#  'MONTHLY_EXPENSE_ON_DOMESTIC_HELP',
#  'MONTHLY_EXPENSE_ON_MOTOR_VEHICLE_REPAIRS',
#  'MONTHLY_EXPENSE_ON_REMITTANCES_SENT',
#  'MONTHLY_EXPENSE_ON_SOCIAL_OBLIGATIONS',
#  'MONTHLY_EXPENSE_ON_RELIGIOUS_OBLIGATIONS',
#  'MONTHLY_EXPENSE_ON_PROFESSIONAL_CONSULTATION',
#  'MONTHLY_EXPENSE_ON_GENERAL_INSURANCE',
#  'MONTHLY_EXPENSE_ON_VACATION',
#  'MONTHLY_EXPENSE_ON_LIGHTING',
#  'MONTHLY_EXPENSE_ON_FURNITURE_AND_FURNISHINGS',
#  'MONTHLY_EXPENSE_ON_PAINTING_AND_RENOVATION',
#  'MONTHLY_EXPENSE_ON_UTENSILS',
#  'MONTHLY_EXPENSE_ON_POCKET_MONEY',
#  'MONTHLY_EXPENSE_ON_PETS']

# %%
df['MONTHLY_EXPENSE_ON_MISCELLANEOUS']
# Out:
# 0         5400
# 1         3200
# 2         1650
# 3         1390
# 4         3300
#           ...
# 174400    3990
# 174401      90
# 174402      40
# 174403      55
# 174404     580
# Name: MONTHLY_EXPENSE_ON_MISCELLANEOUS, Length: 174405, dtype: int64

# %% [markdown]
# ###  Extracting csv from Zip files

# %%
path = r'C:\Users\parik\Documents\Data sets\People of India\People of India-20220311T061826Z-001\People of India'
directory_to_extract_to = r'C:\Users\parik\Documents\Data sets\People of India\People of India-20220311T061826Z-001\People of India'
all_files = glob.glob(path + "/*.zip")
for path in all_files:
    with zipfile.ZipFile(path, 'r') as zip_ref:
        zip_ref.extractall(r'C:\Users\parik\Documents\Data sets\People of India\People of India-20220311T061826Z-001\People of India')

# %% [markdown]
# ### Merging all csv files into one large file

# %%
path = r"C:\Users\parik\Documents\Data sets\Consumption Pyramids-20220311T061932Z-001\Consumption Pyramids\Monthly Expenses"
all_files = glob.glob(path + "/*.csv")

# %%
all_files
# Out:
# ['C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140228_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20140930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20141031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20141130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20141231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150228_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20150930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20151031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20151130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20151231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160229_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20160930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20161031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20161130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20161231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170228_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20170930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20171031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20171130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20171231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180228_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20180930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20181031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20181130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20181231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190228_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20191031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20191130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20191231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200229_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200831_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20200930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20201031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20201130_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20201231_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210131_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210228_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210331_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210430_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210531_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210630_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210731_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20210831_MS_rev.csv']

# %%
files2019 = []
for path in all_files:
    if "2019" in path:
        files2019.append(path)

# %%
files2019 = files2019[-4:-1]
files2019
# Out:
# ['C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20190930_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20191031_MS_rev.csv',
#  'C:\\Users\\parik\\Documents\\Data sets\\Consumption Pyramids-20220311T061932Z-001\\Consumption Pyramids\\Monthly Expenses\\consumption_pyramids_20191130_MS_rev.csv']

# %%
li = []

for filename in files2019:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.shape
# Out:
# (523215, 211)

# %%
random_df = frame['HH_ID'] == 69585858
random_df.sum()
# Out:
# 3

# %%
particular_hhid = frame[frame['HH_ID'] == 69585858]

# %%
misc_exp = frame.groupby('HH_ID').agg({'MONTHLY_EXPENSE_ON_MISCELLANEOUS':np.sum})

# %%
exps = particular_hhid['MONTHLY_EXPENSE_ON_MISCELLANEOUS'].sum()
exps
# Out:
# 3510

# %%
df_merged = pd.read_csv('df_merged_ex.csv')

# %%
df_merged.columns
# Out:
# Index(['Unnamed: 0', 'WAVE_NO', 'HH_ID', 'STATE', 'HR', 'DISTRICT',
#        'REGION_TYPE', 'STRATUM', 'PSU_ID', 'MONTH_SLOT',
#        ...
#        'POWER_AVAILABILITY_IN_HOURS_PER_DAY', 'HAS_ACCESS_TO_WATER_IN_HOUSE',
#        'WATER_AVAILABILITY_IN_DAYS_PER_WEEK',
#        'WATER_AVAILABILITY_IN_HOURS_PER_DAY', 'HAS_TOILET_IN_HOUSE',
#        'TIME_TO_TRAVEL_TEN_KMS', 'MEM_ID', 'gender_of_oldest_unmarried',
#        'age_of_oldest_unmarried', 'is_bride'],
#       dtype='object', length=305)

# %%
df_merged.drop('Unnamed: 0',axis = 1,inplace=True)

# %%
df_merged
# Out:
#      WAVE_NO     HH_ID             STATE      HR          DISTRICT  \
# 0         18  10163434   Jammu & Kashmir    HR 1         Bandipore
# 1         18  18836801   Jammu & Kashmir    HR 1         Bandipore
# 2         18  37416292  Himachal Pradesh    HR 3               Una
# 3         18  69997063  Himachal Pradesh    HR 3             Solan
# 4         18  83532467  Himachal Pradesh    HR 3           Sirmaur
# ..       ...       ...               ...     ...               ...
# 857       18  64408703           Tripura  HR 109     North Tripura
# 858       18  69585858           Tripura  HR 109     North Tripura
# 859       18  87985798         Meghalaya  HR 110  East Khasi Hills
# 860       18  16619392         Meghalaya  HR 110  East Khasi Hills
# 861       18  55046501         Meghalaya  HR 110  East Khasi Hills
#
#     REGION_TYPE         STRATUM        PSU_ID MONTH_SLOT RESPONSE_STATUS  ...  \
# 0         RURAL    HR 1_RURAL_R   PSU_ID_7960   Sep 2019        Accepted  ...
# 1         RURAL    HR 1_RURAL_R   PSU_ID_7963   Sep 2019        Accepted  ...
# 2         RURAL    HR 3_RURAL_R   PSU_ID_8061   Oct 2019        Accepted  ...
# 3         RURAL    HR 3_RURAL_R   PSU_ID_8067   Sep 2019        Accepted  ...
# 4         RURAL    HR 3_RURAL_R   PSU_ID_8069   Sep 2019        Accepted  ...
# ..          ...             ...           ...        ...             ...  ...
# 857       RURAL  HR 109_RURAL_R  PSU_ID_12845   Sep 2019        Accepted  ...
# 858       RURAL  HR 109_RURAL_R  PSU_ID_12846   Oct 2019        Accepted  ...
# 859       URBAN  HR 110_URBAN_M   PSU_ID_7944   Oct 2019        Accepted  ...
# 860       URBAN  HR 110_URBAN_M   PSU_ID_7944   Oct 2019        Accepted  ...
# 861       URBAN  HR 110_URBAN_M   PSU_ID_7944   Dec 2019        Accepted  ...
#
#     POWER_AVAILABILITY_IN_HOURS_PER_DAY HAS_ACCESS_TO_WATER_IN_HOUSE  \
# 0                                    14                            Y
# 1                                    24                            Y
# 2                                    23                            Y
# 3                                    24                            Y
# 4                                    23                            Y
# ..                                  ...                          ...
# 857                                  20                            Y
# 858                                  20                            Y
# 859                                  24                            Y
# 860                                  24                            Y
# 861                                  24                            N
#
#      WATER_AVAILABILITY_IN_DAYS_PER_WEEK  WATER_AVAILABILITY_IN_HOURS_PER_DAY  \
# 0                                      7                                   24
# 1                                      7                                   24
# 2                                      7                                    7
# 3                                      7                                    7
# 4                                      7                                    8
# ..                                   ...                                  ...
# 857                                    7                                   24
# 858                                    7                                   24
# 859                                    7                                   24
# 860                                    7                                   24
# 861                                 -100                                 -100
#
#      HAS_TOILET_IN_HOUSE  TIME_TO_TRAVEL_TEN_KMS  MEM_ID  \
# 0                      Y                      30       4
# 1                      Y                      25       4
# 2                      Y                      22       3
# 3                      Y                      25       4
# 4                      Y                      24       3
# ..                   ...                     ...     ...
# 857                    Y                      55       3
# 858                    Y                      55       3
# 859                    Y                      28       4
# 860                    Y                      24       3
# 861                    N                      26       3
#
#      gender_of_oldest_unmarried age_of_oldest_unmarried is_bride
# 0                             F                      22     True
# 1                             F                      29     True
# 2                             M                      33    False
# 3                             M                      27    False
# 4                             F                      28     True
# ..                          ...                     ...      ...
# 857                           M                      27    False
# 858                           M                      25    False
# 859                           M                      26    False
# 860                           M                      19    False
# 861                           F                      28     True
#
# [862 rows x 304 columns]

# %%
merged_exps = pd.merge(misc_exp,df_merged, how = "inner", on = "HH_ID")
list(merged_exps.columns)
# Out:
# ['HH_ID',
#  'MONTHLY_EXPENSE_ON_MISCELLANEOUS',
#  'WAVE_NO',
#  'STATE',
#  'HR',
#  'DISTRICT',
#  'REGION_TYPE',
#  'STRATUM',
#  'PSU_ID',
#  'MONTH_SLOT',
#  'RESPONSE_STATUS',
#  'REASON_FOR_NON_RESPONSE',
#  'FAMILY_SHIFTED',
#  'HH_WEIGHT_W',
#  'HH_WEIGHT_FOR_COUNTRY_W',
#  'HH_WEIGHT_FOR_STATE_W',
#  'HH_NON_RESPONSE_W',
#  'HH_NON_RESPONSE_FOR_COUNTRY_W',
#  'HH_NON_RESPONSE_FOR_STATE_W',
#  'AGE_GROUP',
#  'INCOME_GROUP',
#  'OCCUPATION_GROUP',
#  'EDUCATION_GROUP',
#  'GENDER_GROUP',
#  'WATER_GROUP',
#  'POWER_GROUP',
#  'TRAVEL_GROUP',
#  'SIZE_GROUP',
#  'HOUSES_OWNED',
#  'BOUGHT_HOUSE',
#  'WILL_BUY_HOUSE',
#  'WILL_BUY_HOUSE_NOW',
#  'GOOD_TIME_TO_BUY_HOUSE',
#  'REFRIGERATORS_OWNED',
#  'BOUGHT_REFRIGERATOR',
#  'WILL_BUY_REFRIGERATOR',
#  'WILL_BUY_REFRIGERATOR_NOW',
#  'GOOD_TIME_TO_BUY_REFRIGERATOR',
#  'AIR_CONDITIONERS_OWNED',
#  'BOUGHT_AIR_CONDITIONER',
#  'WILL_BUY_AIR_CONDITIONER',
#  'WILL_BUY_AIR_CONDITIONER_NOW',
#  'GOOD_TIME_TO_BUY_AIR_CONDITIONER',
#  'COOLERS_OWNED',
#  'BOUGHT_COOLER',
#  'WILL_BUY_COOLER',
#  'WILL_BUY_COOLER_NOW',
#  'GOOD_TIME_TO_BUY_COOLER',
#  'WASHING_MACHINES_OWNED',
#  'BOUGHT_WASHING_MACHINE',
#  'WILL_BUY_WASHING_MACHINE',
#  'WILL_BUY_WASHING_MACHINE_NOW',
#  'GOOD_TIME_TO_BUY_WASHING_MACHINE',
#  'TELEVISIONS_OWNED',
#  'BOUGHT_TELEVISION',
#  'WILL_BUY_TELEVISION',
#  'WILL_BUY_TELEVISION_NOW',
#  'GOOD_TIME_TO_BUY_TELEVISION',
#  'COMPUTERS_OWNED',
#  'BOUGHT_COMPUTER',
#  'WILL_BUY_COMPUTER',
#  'WILL_BUY_COMPUTER_NOW',
#  'GOOD_TIME_TO_BUY_COMPUTER',
#  'CARS_OWNED',
#  'TYPE_OF_CAR_OWNED',
#  'BOUGHT_CAR',
#  'WILL_BUY_CAR',
#  'WILL_BUY_CAR_OF_TYPE',
#  'WILL_BUY_CAR_NOW',
#  'GOOD_TIME_TO_BUY_CAR',
#  'TWO_WHEELERS_OWNED',
#  'TYPE_OF_TWO_WHEELER_OWNED',
#  'BOUGHT_TWO_WHEELER',
#  'WILL_BUY_TWO_WHEELER',
#  'WILL_BUY_TWO_WHEELER_OF_TYPE',
#  'WILL_BUY_TWO_WHEELER_NOW',
#  'GOOD_TIME_TO_BUY_TWO_WHEELER',
#  'GENSET_INVERTERS_OWNED',
#  'BOUGHT_GENSET_INVERTER',
#  'WILL_BUY_GENSET_INVERTER',
#  'WILL_BUY_GENSET_INVERTER_NOW',
#  'GOOD_TIME_TO_BUY_GENSET_INVERTER',
#  'TRACTORS_OWNED',
#  'BOUGHT_TRACTOR',
#  'WILL_BUY_TRACTOR',
#  'WILL_BUY_TRACTOR_NOW',
#  'GOOD_TIME_TO_BUY_TRACTOR',
#  'CATTLE_OWNED',
#  'BOUGHT_CATTLE',
#  'WILL_BUY_CATTLE',
#  'WILL_BUY_CATTLE_NOW',
#  'GOOD_TIME_TO_BUY_CATTLE',
#  'HAS_OUTSTANDING_SAVING_IN_FIXED_DEPOSITS',
#  'HAS_SAVED_IN_FIXED_DEPOSITS',
#  'WILL_SAVE_IN_FIXED_DEPOSITS',
#  'HAS_OUTSTANDING_SAVING_IN_POST_OFFICE_SAVINGS',
#  'HAS_SAVED_IN_POST_OFFICE_SAVINGS',
#  'WILL_SAVE_IN_POST_OFFICE_SAVINGS',
#  'HAS_OUTSTANDING_SAVING_IN_NSC_BONDS',
#  'HAS_SAVED_IN_NSC_BONDS',
#  'WILL_SAVE_IN_NSC_BONDS',
#  'HAS_OUTSTANDING_SAVING_IN_KVP',
#  'HAS_SAVED_IN_KVP',
#  'WILL_SAVE_IN_KVP',
#  'HAS_OUTSTANDING_SAVING_IN_PROVIDENT_FUND',
#  'HAS_SAVED_IN_PROVIDENT_FUND',
#  'WILL_SAVE_IN_PROVIDENT_FUND',
#  'HAS_OUTSTANDING_SAVING_IN_LIFE_INSURANCE',
#  'HAS_SAVED_IN_LIFE_INSURANCE',
#  'WILL_SAVE_IN_LIFE_INSURANCE',
#  'HAS_OUTSTANDING_SAVING_IN_MUTUAL_FUNDS',
#  'HAS_SAVED_IN_MUTUAL_FUNDS',
#  'WILL_SAVE_IN_MUTUAL_FUNDS',
#  'HAS_OUTSTANDING_SAVING_IN_LISTED_SHARES',
#  'HAS_SAVED_IN_LISTED_SHARES',
#  'WILL_SAVE_IN_LISTED_SHARES',
#  'HAS_OUTSTANDING_SAVING_IN_BUSINESS',
#  'HAS_SAVED_IN_BUSINESS',
#  'WILL_SAVE_IN_BUSINESS',
#  'HAS_OUTSTANDING_SAVING_IN_GOLD',
#  'HAS_SAVED_IN_GOLD',
#  'WILL_SAVE_IN_GOLD',
#  'HAS_OUTSTANDING_SAVING_IN_REAL_ESTATE',
#  'HAS_SAVED_IN_REAL_ESTATE',
#  'WILL_SAVE_IN_REAL_ESTATE',
#  'HAS_OUTSTANDING_SAVING_IN_CHIT_FUNDS',
#  'HAS_SAVED_IN_CHIT_FUNDS',
#  'WILL_SAVE_IN_CHIT_FUNDS',
#  'HAS_OUTSTANDING_SAVING_IN_OTHER_FIN_INSTRUMENTS',
#  'HAS_SAVED_IN_OTHER_FIN_INSTRUMENTS',
#  'WILL_SAVE_IN_OTHER_FIN_INSTRUMENTS',
#  'HAS_OUTSTANDING_BORROWING',
#  'BORROWED_FOR_HOUSING',
#  'BORROWED_FOR_EDUCATION',
#  'BORROWED_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FOR_WEDDING',
#  'BORROWED_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FOR_CONSUMER_DURABLES',
#  'BORROWED_FOR_BUSINESS',
#  'BORROWED_FOR_INVESTMENTS',
#  'BORROWED_FOR_DEBT_REPAYMENT',
#  'BORROWED_FOR_VEHICLES',
#  'BORROWED_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_BANK',
#  'BORROWED_FROM_BANK_FOR_HOUSING',
#  'BORROWED_FROM_BANK_FOR_EDUCATION',
#  'BORROWED_FROM_BANK_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_BANK_FOR_WEDDING',
#  'BORROWED_FROM_BANK_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_BANK_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_BANK_FOR_BUSINESS',
#  'BORROWED_FROM_BANK_FOR_INVESTMENTS',
#  'BORROWED_FROM_BANK_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_BANK_FOR_VEHICLES',
#  'BORROWED_FROM_BANK_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_MONEY_LENDER',
#  'BORROWED_FROM_MONEY_LENDER_FOR_HOUSING',
#  'BORROWED_FROM_MONEY_LENDER_FOR_EDUCATION',
#  'BORROWED_FROM_MONEY_LENDER_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_MONEY_LENDER_FOR_WEDDING',
#  'BORROWED_FROM_MONEY_LENDER_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_MONEY_LENDER_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_MONEY_LENDER_FOR_BUSINESS',
#  'BORROWED_FROM_MONEY_LENDER_FOR_INVESTMENTS',
#  'BORROWED_FROM_MONEY_LENDER_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_MONEY_LENDER_FOR_VEHICLES',
#  'BORROWED_FROM_MONEY_LENDER_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_EMPLOYER',
#  'BORROWED_FROM_EMPLOYER_FOR_HOUSING',
#  'BORROWED_FROM_EMPLOYER_FOR_EDUCATION',
#  'BORROWED_FROM_EMPLOYER_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_EMPLOYER_FOR_WEDDING',
#  'BORROWED_FROM_EMPLOYER_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_EMPLOYER_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_EMPLOYER_FOR_BUSINESS',
#  'BORROWED_FROM_EMPLOYER_FOR_INVESTMENTS',
#  'BORROWED_FROM_EMPLOYER_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_EMPLOYER_FOR_VEHICLES',
#  'BORROWED_FROM_EMPLOYER_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_REL_FRIENDS',
#  'BORROWED_FROM_REL_FRIENDS_FOR_HOUSING',
#  'BORROWED_FROM_REL_FRIENDS_FOR_EDUCATION',
#  'BORROWED_FROM_REL_FRIENDS_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_REL_FRIENDS_FOR_WEDDING',
#  'BORROWED_FROM_REL_FRIENDS_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_REL_FRIENDS_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_REL_FRIENDS_FOR_BUSINESS',
#  'BORROWED_FROM_REL_FRIENDS_FOR_INVESTMENTS',
#  'BORROWED_FROM_REL_FRIENDS_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_REL_FRIENDS_FOR_VEHICLES',
#  'BORROWED_FROM_REL_FRIENDS_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_NBFC_DEALER',
#  'BORROWED_FROM_NBFC_DEALER_FOR_HOUSING',
#  'BORROWED_FROM_NBFC_DEALER_FOR_EDUCATION',
#  'BORROWED_FROM_NBFC_DEALER_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_NBFC_DEALER_FOR_WEDDING',
#  'BORROWED_FROM_NBFC_DEALER_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_NBFC_DEALER_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_NBFC_DEALER_FOR_BUSINESS',
#  'BORROWED_FROM_NBFC_DEALER_FOR_INVESTMENTS',
#  'BORROWED_FROM_NBFC_DEALER_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_NBFC_DEALER_FOR_VEHICLES',
#  'BORROWED_FROM_NBFC_DEALER_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_SHG',
#  'BORROWED_FROM_SHG_FOR_HOUSING',
#  'BORROWED_FROM_SHG_FOR_EDUCATION',
#  'BORROWED_FROM_SHG_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_SHG_FOR_WEDDING',
#  'BORROWED_FROM_SHG_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_SHG_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_SHG_FOR_BUSINESS',
#  'BORROWED_FROM_SHG_FOR_INVESTMENTS',
#  'BORROWED_FROM_SHG_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_SHG_FOR_VEHICLES',
#  'BORROWED_FROM_SHG_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_MFI',
#  'BORROWED_FROM_MFI_FOR_HOUSING',
#  'BORROWED_FROM_MFI_FOR_EDUCATION',
#  'BORROWED_FROM_MFI_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_MFI_FOR_WEDDING',
#  'BORROWED_FROM_MFI_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_MFI_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_MFI_FOR_BUSINESS',
#  'BORROWED_FROM_MFI_FOR_INVESTMENTS',
#  'BORROWED_FROM_MFI_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_MFI_FOR_VEHICLES',
#  'BORROWED_FROM_MFI_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_CHITFUNDS',
#  'BORROWED_FROM_CHITFUNDS_FOR_HOUSING',
#  'BORROWED_FROM_CHITFUNDS_FOR_EDUCATION',
#  'BORROWED_FROM_CHITFUNDS_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_CHITFUNDS_FOR_WEDDING',
#  'BORROWED_FROM_CHITFUNDS_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_CHITFUNDS_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_CHITFUNDS_FOR_BUSINESS',
#  'BORROWED_FROM_CHITFUNDS_FOR_INVESTMENTS',
#  'BORROWED_FROM_CHITFUNDS_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_CHITFUNDS_FOR_VEHICLES',
#  'BORROWED_FROM_CHITFUNDS_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_CREDIT_CARDS',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_HOUSING',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_EDUCATION',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_WEDDING',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_BUSINESS',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_INVESTMENTS',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_VEHICLES',
#  'BORROWED_FROM_CREDIT_CARDS_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_SHOPS',
#  'BORROWED_FROM_SHOPS_FOR_HOUSING',
#  'BORROWED_FROM_SHOPS_FOR_EDUCATION',
#  'BORROWED_FROM_SHOPS_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_SHOPS_FOR_WEDDING',
#  'BORROWED_FROM_SHOPS_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_SHOPS_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_SHOPS_FOR_VEHICLES',
#  'BORROWED_FROM_SHOPS_FOR_BUSINESS',
#  'BORROWED_FROM_SHOPS_FOR_INVESTMENTS',
#  'BORROWED_FROM_SHOPS_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_SHOPS_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_OTHER_SOURCES',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_HOUSING',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_EDUCATION',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_WEDDING',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_BUSINESS',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_INVESTMENTS',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_VEHICLES',
#  'BORROWED_FROM_OTHER_SOURCES_FOR_OTHER_PURPOSES',
#  'BORROWED_FROM_DONT_KNOW',
#  'BORROWED_FROM_DONT_KNOW_FOR_HOUSING',
#  'BORROWED_FROM_DONT_KNOW_FOR_EDUCATION',
#  'BORROWED_FROM_DONT_KNOW_FOR_MEDICAL_EXPENDITURE',
#  'BORROWED_FROM_DONT_KNOW_FOR_WEDDING',
#  'BORROWED_FROM_DONT_KNOW_FOR_CONSUMPTION_EXPENDITURE',
#  'BORROWED_FROM_DONT_KNOW_FOR_CONSUMER_DURABLES',
#  'BORROWED_FROM_DONT_KNOW_FOR_BUSINESS',
#  'BORROWED_FROM_DONT_KNOW_FOR_INVESTMENTS',
#  'BORROWED_FROM_DONT_KNOW_FOR_DEBT_REPAYMENT',
#  'BORROWED_FROM_DONT_KNOW_FOR_VEHICLES',
#  'BORROWED_FROM_DONT_KNOW_FOR_OTHER_PURPOSES',
#  'FAMILY_FINANCES_COMPARED_TO_YEAR_AGO',
#  'FAMILY_FINANCES_A_YEAR_LATER',
#  'CONDITIONS_IN_COUNTRY_OVER_NEXT_12_MONTHS',
#  'CONDITIONS_IN_COUNTRY_OVER_NEXT_5_YEARS',
#  'IS_THIS_GOOD_TIME_TO_BUY_CONSUMER_DURABLES',
#  'TYPE_OF_ROOF',
#  'TYPE_OF_WALL',
#  'HAS_ACCESS_TO_ELECTRICITY',
#  'POWER_AVAILABILITY_IN_HOURS_PER_DAY',
#  'HAS_ACCESS_TO_WATER_IN_HOUSE',
#  'WATER_AVAILABILITY_IN_DAYS_PER_WEEK',
#  'WATER_AVAILABILITY_IN_HOURS_PER_DAY',
#  'HAS_TOILET_IN_HOUSE',
#  'TIME_TO_TRAVEL_TEN_KMS',
#  'MEM_ID',
#  'gender_of_oldest_unmarried',
#  'age_of_oldest_unmarried',
#  'is_bride']

# %%
bride = merged_exps['is_bride']
groom = ~bride

# %%
merged_exps[bride]["MONTHLY_EXPENSE_ON_MISCELLANEOUS"].mean()
# Out:
# 6457.441935483871

# %%
merged_exps[groom]["MONTHLY_EXPENSE_ON_MISCELLANEOUS"].mean()
# Out:
# 4011.4384057971015

# %%
frame["MONTHLY_EXPENSE_ON_MISCELLANEOUS"].mean()
# Out:
# 967.7982091492025

# %%
merged_exps.columns
# Out:
# Index(['HH_ID', 'MONTHLY_EXPENSE_ON_MISCELLANEOUS', 'WAVE_NO', 'STATE', 'HR',
#        'DISTRICT', 'REGION_TYPE', 'STRATUM', 'PSU_ID', 'MONTH_SLOT',
#        ...
#        'POWER_AVAILABILITY_IN_HOURS_PER_DAY', 'HAS_ACCESS_TO_WATER_IN_HOUSE',
#        'WATER_AVAILABILITY_IN_DAYS_PER_WEEK',
#        'WATER_AVAILABILITY_IN_HOURS_PER_DAY', 'HAS_TOILET_IN_HOUSE',
#        'TIME_TO_TRAVEL_TEN_KMS', 'MEM_ID', 'gender_of_oldest_unmarried',
#        'age_of_oldest_unmarried', 'is_bride'],
#       dtype='object', length=305)
